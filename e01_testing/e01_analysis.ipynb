# %%
import pandas as pd

# %%
df = pd.read_csv('metrics.csv')
df
# Out:
#     mean_absolute_error  std_absolute_error  mean_relative_error
# 0              0.835175            0.721077             0.001980  \
# 1            424.821416           23.996594             0.995896
# 2              0.842950            0.729000             0.001999
# 3            423.290606           23.695539             0.992170
# 4              0.847696            0.722863             0.002007
# ..                  ...                 ...                  ...
# 59             0.840923            0.719387             0.001994
# 60             0.847515            0.738646             0.002008
# 61             0.823987            0.708392             0.001951
# 62             0.846125            0.727283             0.002004
# 63             0.828286            0.708021             0.001964
#
#     std_relative_error            output_col  one_hot  normalize
# 0             0.001768  cycle_length_in_days     True       True  \
# ...
