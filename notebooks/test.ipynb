# %%
import pandas as pd
import numpy as np
import math

# %%
df = pd.read_csv('../plot_excel.csv')
df['sq_diff'] = (df['rho_pred'] - df['rho_true'])**2
rmse = df.groupby(by='ts_id').agg(rmse = ('sq_diff', 'sum'))
rmse['rmse'] /= math.sqrt(69) / 10000
rmse.sort_values(by='rmse')
# Out:
#            rmse
# ts_id
# 1363   0.008015
# 276    0.008795
# 1602   0.009082
# 447    0.010994
# 1956   0.011022
# ...         ...
# 1998   1.016745
# 151    1.401409
# 1927   1.417669
# 1953   1.461327
# 1170   1.915266
#
# [2000 rows x 1 columns]

# %%
print(f'Avearage RMSE: {rmse.mean()}')
# Out:
# Avearage RMSE: rmse    6.318321
# dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/input_output_data.csv')
df = df.loc[:, ['keff_max', 'ppf_max', 'cycle_length_in_days']]
plt.hist(df['keff_max'])
# Out:
# (array([  24.,  293.,  971., 2096., 2679., 2186., 1143.,  478.,  112.,
#           18.]),
#  array([1.067229 , 1.0806389, 1.0940488, 1.1074587, 1.1208686, 1.1342785,
#         1.1476884, 1.1610983, 1.1745082, 1.1879181, 1.201328 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['ppf_max'])
# Out:
# (array([4.711e+03, 3.115e+03, 1.099e+03, 5.460e+02, 2.970e+02, 1.250e+02,
#         6.900e+01, 2.500e+01, 9.000e+00, 4.000e+00]),
#  array([ 1.979 ,  3.0201,  4.0612,  5.1023,  6.1434,  7.1845,  8.2256,
#          9.2667, 10.3078, 11.3489, 12.39  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['cycle_length_in_days'])
# Out:
# (array([   5.,   33.,  188.,  696., 1811., 2794., 2605., 1468.,  368.,
#           32.]),
#  array([321.738718 , 339.8607964, 357.9828748, 376.1049532, 394.2270316,
#         412.34911  , 430.4711884, 448.5932668, 466.7153452, 484.8374236,
#         502.959502 ]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
sns.pairplot(df)
